# %%
import pandas as pd
from src.data_processing import load_data, basic_eda

# Example: replace the path below with your dataset path
# df = load_data('data/sample_births.csv')
# summary = basic_eda(df)
# print(summary)

print('Edit the `df = load_data(...)` line and run the cells')
